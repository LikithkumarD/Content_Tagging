# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import openai
import json
import os
from langchain.chat_models import AzureChatOpenAI
from langchain.schema import HumanMessage
from langchain import LLMChain
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.prompts import ChatPromptTemplate
import fitz  # PyMuPDF
import re
import time

# %%
openai_api_base="https://triconpoc.openai.azure.com/"
openai_api_version="2023-03-15-preview"
deployment_name="gpt-35-turbo"
openai_api_key = "bfd7d79c2c33409aa58d94044e988e6e"
openai_api_type="azure"

# %%
llm = AzureChatOpenAI(
    openai_api_base=openai_api_base,
    openai_api_version=openai_api_version,
    deployment_name=deployment_name,
    openai_api_key=openai_api_key,
    openai_api_type=openai_api_type,
)
# Out:
# C:\Users\ual-laptop\anaconda3\Lib\site-packages\langchain_core\_api\deprecation.py:119: LangChainDeprecationWarning: The class `AzureChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import AzureChatOpenAI`.
#   warn_deprecated(

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    with fitz.open(pdf_path) as doc:
        for page in doc:
            text += page.get_text()
    return text

def clean_text(text):
    cleaned_text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text).strip()
    return cleaned_text


response_schemas = [
    ResponseSchema(name="Language", description="Language used in the article"),
    ResponseSchema(name="Length", description="Length of the article in words"),
    ResponseSchema(name="Grade_Level", description="Grade level of the content"),
    ResponseSchema(name="Discipline", description="Discipline or subject of the article"),
    ResponseSchema(name="Blooms_Level", description="Bloom's taxonomy level of the content"),
    ResponseSchema(name="Learning_Objectives", description="Learning objectives covered in the article"),
    ResponseSchema(name="Learning_Facets", description="Learning facets addressed in the article")
]


output_parser = StructuredOutputParser.from_response_schemas(response_schemas)
format_instructions = output_parser.get_format_instructions()


example = '''{
    "Language": "English",
    "Length": "1500 words",
    "Grade_Level": "High School",
    "Discipline": "Chemistry",
    "Blooms_Level": "Application",
    "Learning_Objectives": "Understand acid-base theories",
    "Learning_Facets": "Experimental analysis, problem-solving"
}'''


template = """\
You are an educational curriculum expert system tasked to find specific information for the article. 
Identify the following items from the review text:
- Language used in the article
- Length of the article in words
- Grade level of the content (e.g., 10th grade, 12th grade, University)
- Discipline or subject of the article
- Bloom's taxonomy level of the content
- Learning objectives covered in the article
- Learning facets addressed in the article

The review text is delimited with triple backticks.

Take your time to analyze the review text and find the required information.
Output the response in the desired format as given in {example} but don't use the same value.

Make your response as short as possible.
Make sure to answer in the correct format.
Review text: ```{article}```

{format_instructions}

If the information isn't present retry again two times and then use 'unknown' as the value, not null or None.
"""


prompt = ChatPromptTemplate.from_template(template=template)

def process_pdfs_in_directory(directory):
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".pdf"):
                pdf_path = os.path.join(root, file)
                print(f"Processing file: {pdf_path}")
                try:
                    # Extract and clean text from the PDF
                    article_text = extract_text_from_pdf(pdf_path)
                    article_text = clean_text(article_text)
                    
                    # Use the LLMChain to process the prompt
                    chain = prompt | llm
                    inputs = {
                        "article": article_text,
                        "example": example,
                        "format_instructions": format_instructions
                    }
                    response = chain.invoke(inputs)
                    json_string = response.content.strip('```json\n').strip('\n```')
                    data = json.loads(json_string)
                    language = data.get("Language")
                    length = data.get("Length")
                    grade_level = data.get("Grade_Level")
                    discipline = data.get("Discipline")
                    blooms_level = data.get("Blooms_Level")
                    Learning_Objectives = data.get("Learning_Objectives")
                    Learning_Facets = data.get("Learning_Facets")
                    print(f"Length: {length}")
                    print(f"Grade Level: {grade_level}")
                    print(f"Discipline: {discipline}")
                    print(f"Blooms Level: {blooms_level}")
                    print(f"Learning_Objectives: {Learning_Objectives}")
                    print(f"Learning_Facets: {Learning_Facets}")
                    print("----------------------------------------------------------------------------------------")
                except Exception as e:
                    print(f"Error processing {pdf_path}: {e}")
                    print("----------------------------------------------------------------------------------------")
                time.sleep(3)
                
main_directory = r"C:\Users\ual-laptop\Downloads\resources"
process_pdfs_in_directory(main_directory)
# Out:
# Processing file: C:\Users\ual-laptop\Downloads\resources\Article\2024-02-genome-snakefly-evolutionary-history.pdf
# Length: 828 words
# Grade Level: High School
# Discipline: Biology
# Blooms Level: Analysis
# Learning_Objectives: Understand the evolutionary history of snakeflies and the impact of the asteroid on their survival
# Learning_Facets: Genomic analysis, phylogenetic analysis
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Article\2024-03-magnetic-avalanche-triggered-quantum-effects.pdf
# Length: 600 words
# Grade Level: High School
# Discipline: Physics
# Blooms Level: Application
# Learning_Objectives: Understand quantum mechanical effects on the macroscopic scale
# Learning_Facets: Experimental analysis, problem-solving
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Article\2024-03-reveal-evolutionary-path-important-proteins.pdf
# Length: over 500 words
# Grade Level: High School
# Discipline: Biochemistry
# Blooms Level: Application
# Learning_Objectives: Understand the evolutionary pathway of regulatory proteins, gain knowledge on the differences in evolutionary patterns among classes of proteins
# Learning_Facets: Problem-solving, Experimental analysis
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Article\Capturing the acid-base reactions in alcohol _ ScienceDaily.pdf
# Length: 612 words
# Grade Level: High School
# Discipline: Chemistry
# Blooms Level: Application
# Learning_Objectives: Understanding the cooperative role of alcohols, Enhancing reactivity of alcohol cluster, Promoting alcohol cluster to form an effective Brnsted base
# Learning_Facets: Experimental analysis, problem-solving
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Article\New strategy for eye condition could replace injections with eyedrops _ ScienceDaily.pdf
# Length: 578 words
# Grade Level: Unknown
# Discipline: Ophthalmology
# Blooms Level: Application
# Learning_Objectives: Understand the potential of a new compound for treating wet age-related macular degeneration
# Learning_Facets: Experimental analysis, medical research
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Article\Study unlocks the power of visible light for sustainable chemistry _ ScienceDaily.pdf
# Length: approximately 500 words
# Grade Level: High School
# Discipline: Chemistry
# Blooms Level: Application
# Learning_Objectives: To understand the breakthrough in sustainable molecular transformations using visible light to drive chemical processes with greater efficiencies and the potential for a greener future for chemical industries
# Learning_Facets: Environmental sustainability, Cost-effectiveness, Optimized generation of energetic electrons at catalytic sites
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\10-Sc-Acid-Bases-and-Salts-Notes.pdf
# Length: Unknown
# Grade Level: High School
# Discipline: Chemistry
# Blooms Level: Application
# Learning_Objectives: Understand acid-base theories, Identify salts obtained from a given acid-base reaction, Perform pH-based experiments
# Learning_Facets: Experimental analysis, problem-solving
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\100per_science_cl10_nf_ch3.pdf
# Length: 2438 words
# Grade Level: High School
# Discipline: Chemistry
# Blooms Level: Application
# Learning_Objectives: Understand properties of metals and nonmetals, understand chemical reactions of metals and nonmetals, comprehend the process of electrolysis
# Learning_Facets: Experimental analysis, problem-solving
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\Chapter-28.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Chapter\Chapter-28.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 10022 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\Chapter-8.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Chapter\Chapter-8.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 13101 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc101.pdf
# Length: approximately 3500 words
# Grade Level: High School
# Discipline: Chemistry
# Blooms Level: Application
# Learning_Objectives: Understand chemical reactions and equations, learn about types of reactions and their symbolic representation, understand oxidation and reduction reactions, learn about corrosion and rancidity
# Learning_Facets: Experimental analysis, problem-solving, critical thinking
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc102.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Chapter\jesc102.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 8680 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc103.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Chapter\jesc103.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 9201 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc104.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Chapter\jesc104.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 9851 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc105.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Chapter\jesc105.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 10527 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc106.pdf
# Length: 2532 words
# Grade Level: High School
# Discipline: Biology
# Blooms Level: Analysis
# Learning_Objectives: Understand the function of control and coordination in the human body, recognize the role of hormones in animal bodies, describe the process of chemical coordination in plants, compare and contrast nervous and hormonal mechanisms
# Learning_Facets: Critical thinking, analysis, comparison
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc108.pdf
# Length: 1500 words
# Grade Level: High School
# Discipline: Biology
# Blooms Level: Application
# Learning_Objectives: Understand mechanism of inheritance, sex determination, variations arising during reproduction
# Learning_Facets: Genetics, Reproduction
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc109.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Chapter\jesc109.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 12193 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc110.pdf
# Length: 2692 words
# Grade Level: High School
# Discipline: Physics
# Blooms Level: Application
# Learning_Objectives: Understand the human eye, its functions, and defects
# Learning_Facets: Experimental analysis, problem-solving, critical thinking
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc111.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Chapter\jesc111.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 10019 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc112.pdf
# Length: 2117 words
# Grade Level: High School
# Discipline: Physics
# Blooms Level: Application
# Learning_Objectives: Understand the relationship between electricity and magnetism, explain the magnetic field produced by a current carrying conductor, apply Flemings left-hand rule to find the direction of force on a current-carrying conductor
# Learning_Facets: Experimental analysis, problem-solving, safety measures
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc113.pdf
# Length: 2500 words
# Grade Level: High School
# Discipline: Environmental Science
# Blooms Level: Application
# Learning_Objectives: Understanding ecosystem, food chains and webs, biodegradable and nonbiodegradable wastes, impact of human activities on the environment
# Learning_Facets: Experimental analysis, problem-solving, critical thinking
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc1an.pdf
# Length: unknown
# Grade Level: High School
# Discipline: Science
# Blooms Level: Application
# Learning_Objectives: Understand acid-base theories
# Learning_Facets: Experimental analysis, problem-solving
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\jesc1ps.pdf
# Length: 1500 words
# Grade Level: High School
# Discipline: Science (Integrated approach to Physics, Chemistry, Biology, and Environmental Science)
# Blooms Level: Application
# Learning_Objectives: To present a coherent coverage of scientific concepts related to our daily life, to address relevant social concerns, to encourage debates on management concerns for sustainable development, to help students construct their own knowledge through hands-on activities, and to provide problems of different difficulty levels.
# Learning_Facets: Hands-on experimentation, social awareness, critical thinking, problem-solving
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\VIII Science Ch-2.pdf
# Length: 1100 words
# Grade Level: 8th grade
# Discipline: Science
# Blooms Level: Application
# Learning_Objectives: Understand physical and chemical properties of metals and non-metals
# Learning_Facets: Observation, analysis, classification, experimentation
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Chapter\harmful-content-llm\jesc107.pdf
# Length: 2976 words
# Grade Level: High School
# Discipline: Biology
# Blooms Level: Application
# Learning_Objectives: Understand the different modes of reproduction in organisms, describe the male and female reproductive systems in humans, explain the process of sexual reproduction in flowering plants, identify different methods of contraception
# Learning_Facets: Reproductive modes, anatomy and physiology, plant reproduction, health literacy
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Research_Paper\Acids-Bases Theory-111.pdf
# Length: 2600 words
# Grade Level: High School
# Discipline: Chemistry
# Blooms Level: Application
# Learning_Objectives: Understand characteristics, properties, and relations of acids and bases; classify acids and bases based on their structure and strength; comprehend neutralization and salt formation reactions
# Learning_Facets: Experimental analysis, problem-solving, recall
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Research_Paper\BIOLOGICAL EFFECTS OF MAGNETIC FIELDS.pdf
# Length: 3534 words
# Grade Level: University
# Discipline: Electromagnetism
# Blooms Level: Application
# Learning_Objectives: Understand the potential health risks associated with magnetic fields, Learn about the interaction mechanisms between magnetic fields and biological systems, Understand the guidelines for occupational and public exposure to static and ELF magnetic fields
# Learning_Facets: Experimental analysis, Problem-solving
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Research_Paper\Coordination and Control Structures and Processes.pdf
# Error processing C:\Users\ual-laptop\Downloads\resources\Research_Paper\Coordination and Control Structures and Processes.pdf: Error code: 400 - {'error': {'message': "This model's maximum context length is 8192 tokens. However, your messages resulted in 16269 tokens. Please reduce the length of the messages.", 'type': 'invalid_request_error', 'param': 'messages', 'code': 'context_length_exceeded'}}
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Research_Paper\EiC v1i2 The Theory of Acids and Bases_tcm18-230799.pdf
# Length: 3017 words
# Grade Level: High School
# Discipline: Chemistry
# Blooms Level: Application
# Learning_Objectives: Understand acid-base theories, calculations of pH in acid-base systems, detection of endpoints in acid-base titrations, polyprotic acids and bases
# Learning_Facets: Experimental analysis, problem-solving
# ----------------------------------------------------------------------------------------
# Processing file: C:\Users\ual-laptop\Downloads\resources\Research_Paper\Study of the Human Eye Working Principle.pdf
# Length: 1935 words
# Grade Level: University
# Discipline: Antenna Design Theory
# Blooms Level: Analysis
# Learning_Objectives: Understand the working principle of the human eye as a detector, analyze the solutions for the main common tradeoffs of antenna array systems, study detecting strategies of the human eye for microwave and millimeter imagining systems and Smart antennas MIMO or any kind of array antenna configuration
# Learning_Facets: Optical coherence tomography, chemistry reactions of the reception mechanism of a photon by a cone, inherent coherence of the human eye as a detector of photons, recycling technique of the cones, direct detection strategy
# ----------------------------------------------------------------------------------------
